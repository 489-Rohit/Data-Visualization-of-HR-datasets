# %%
import numpy as np
import pandas as pd
import datetime

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Downloads\HRDataset_v14.csv")
df.head(5)
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df.describe(include = object)
# Out:
#               Employee_Name                 Position State       DOB  Sex  \
# count                   311                      311   311       311  311
# unique                  311                       32    28       307    2
# top     Adinolfi, Wilson  K  Production Technician I    MA  09/09/65    F
# freq                      1                      137   276         2  176
#
#        MaritalDesc CitizenDesc HispanicLatino RaceDesc DateofHire  \
# count          311         311            311      311        311
# unique           5           3              4        6        101
# top         Single  US Citizen             No    White  1/10/2011
# freq           137         295            282      187         14
#
#        DateofTermination         TermReason EmploymentStatus  \
# count                104                311              311
# unique                96                 18                3
# top            8/19/2018  N/A-StillEmployed           Active
# ...

# %%
column_with_null_value = []
column_with_non_null_value = []
for col in df.columns:
    if df[col].isnull().sum() == 0:
        column_with_non_null_value.append(col)
    else:
        column_with_null_value.append(col)
print(column_with_null_value)
# Out:
# ['DateofTermination', 'ManagerID']

# %%
# PROBLEM STATEMENT 
# Employee_Name having comma instead of space
# Having null value in ['DateofTermination', 'ManagerID'] column

# %%
df["Employee_Name"].unique()
# Out:
# array(['Adinolfi, Wilson  K', 'Ait Sidi, Karthikeyan   ',
#        'Akinkuolie, Sarah', 'Alagbe,Trina', 'Anderson, Carol ',
#        'Anderson, Linda  ', 'Andreola, Colby', 'Athwal, Sam',
#        'Bachiochi, Linda', 'Bacong, Alejandro ', 'Baczenski, Rachael  ',
#        'Barbara, Thomas', 'Barbossa, Hector', 'Barone, Francesco  A',
#        'Barton, Nader', 'Bates, Norman', 'Beak, Kimberly  ',
#        'Beatrice, Courtney ', 'Becker, Renee', 'Becker, Scott',
#        'Bernstein, Sean', 'Biden, Lowan  M', 'Billis, Helen',
#        'Blount, Dianna', 'Bondwell, Betsy', 'Booth, Frank',
#        'Boutwell, Bonalyn', 'Bozzi, Charles', 'Brill, Donna',
#        'Brown, Mia', 'Buccheri, Joseph  ', 'Bugali, Josephine ',
#        'Bunbury, Jessica', 'Burke, Joelle', 'Burkett, Benjamin ',
#        'Cady, Max ', 'Candie, Calvin', 'Carabbio, Judith',
#        'Carey, Michael  ', 'Carr, Claudia  N', 'Carter, Michelle ',
#        'Chace, Beatrice ', 'Champaigne, Brian', 'Chan, Lin',
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df.describe(include= object)
# Out:
#               Employee_Name                 Position State       DOB  Sex  \
# count                   311                      311   311       311  311
# unique                  311                       32    28       307    2
# top     Adinolfi, Wilson  K  Production Technician I    MA  09/09/65    F
# freq                      1                      137   276         2  176
#
#        MaritalDesc CitizenDesc HispanicLatino RaceDesc DateofHire  \
# count          311         311            311      311        311
# unique           5           3              4        6        101
# top         Single  US Citizen             No    White  1/10/2011
# freq           137         295            282      187         14
#
#        DateofTermination         TermReason EmploymentStatus  \
# count                104                311              311
# unique                96                 18                3
# top            8/19/2018  N/A-StillEmployed           Active
# ...

# %%
df["Employee_Name"].nunique()
# Out:
# 311

# %%
df["EmpID"].nunique()
# Out:
# 311

# %%
df["MarriedID"].nunique()
# Out:
# 2

# %%
df["MarriedID"].sort_values(ascending = True)
# Out:
# 0      0
# 171    0
# 172    0
# 174    0
# 175    0
#       ..
# 219    1
# 220    1
# 221    1
# 215    1
# 114    1
# Name: MarriedID, Length: 311, dtype: int64

# %%
df["MaritalStatusID"].nunique()
# Out:
# 5

# %%
df["MaritalStatusID"].unique()
# Out:
# array([0, 1, 2, 4, 3], dtype=int64)

# %%
df["MaritalStatusID"].sort_values()
# Out:
# 0      0
# 149    0
# 153    0
# 309    0
# 162    0
#       ..
# 237    4
# 171    4
# 175    4
# 280    4
# 310    4
# Name: MaritalStatusID, Length: 311, dtype: int64

# %%
df["GenderID"].nunique()
# Out:
# 2

# %%
df["GenderID"].sort_values()
# Out:
# 310    0
# 129    0
# 130    0
# 131    0
# 132    0
#       ..
# 156    1
# 157    1
# 159    1
# 128    1
# 155    1
# Name: GenderID, Length: 311, dtype: int64

# %%
df["EmpStatusID"].nunique()
# Out:
# 5

# %%
df["EmpStatusID"].sort_values(ascending=True)
# Out:
# 0      1
# 165    1
# 166    1
# 167    1
# 170    1
#       ..
# 185    5
# 227    5
# 226    5
# 80     5
# 163    5
# Name: EmpStatusID, Length: 311, dtype: int64

# %%
df["DeptID"].nunique()
# Out:
# 6

# %%
df['DeptID']
# Out:
# 0      5
# 1      3
# 2      5
# 3      5
# 4      5
#       ..
# 306    5
# 307    5
# 308    3
# 309    3
# 310    5
# Name: DeptID, Length: 311, dtype: int64

# %%
df["PerfScoreID"].nunique()
# Out:
# 4

# %%
df["FromDiversityJobFairID"].nunique()
# Out:
# 2

# %%
df["FromDiversityJobFairID"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 306    0
# 307    0
# 308    0
# 309    0
# 310    0
# Name: FromDiversityJobFairID, Length: 311, dtype: int64

# %%
df["Salary"].nunique()
# Out:
# 308

# %%
df["Termd"].nunique()
# Out:
# 2

# %%
df["Termd"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 306    0
# 307    1
# 308    0
# 309    0
# 310    0
# Name: Termd, Length: 311, dtype: int64

# %%
df["PositionID"].nunique()
# Out:
# 30

# %%
df["PositionID"]
# Out:
# 0      19
# 1      27
# 2      20
# 3      19
# 4      19
#        ..
# 306    20
# 307    19
# 308     6
# 309     9
# 310    19
# Name: PositionID, Length: 311, dtype: int64

# %%
df["Position"].nunique()
# Out:
# 32

# %%
df["State"].nunique()
# Out:
# 28

# %%
df["State"].sort_values(ascending= True)
# Out:
# 67     AL
# 288    AZ
# 77     CA
# 149    CO
# 61     CT
#        ..
# 166    UT
# 32     VA
# 40     VT
# 60     VT
# 72     WA
# Name: State, Length: 311, dtype: object

# %%
df["Zip"].nunique()
# Out:
# 158

# %%
df["Zip"].sort_values(ascending =True)
# Out:
# 30      1013
# 204     1040
# 284     1420
# 235     1420
# 189     1450
#        ...
# 288    85006
# 267    89139
# 77     90007
# 278    97756
# 72     98052
# Name: Zip, Length: 311, dtype: int64

# %%
df["DOB"].nunique()
# Out:
# 307

# %%
df["DOB"].sort_values(ascending = True)
# Out:
# 41     01/02/51
# 244    01/04/64
# 126    01/04/84
# 235    01/07/74
# 236    01/07/85
#          ...
# 20     12/22/70
# 171    12/26/76
# 21     12/27/58
# 166    12/27/88
# 229    12/31/84
# Name: DOB, Length: 311, dtype: object

# %%
# Problem Statement
# In DOB column there is some irelevant year and wrong dtype

# %%
df["Sex"].unique()
# Out:
# array(['M ', 'F'], dtype=object)

# %%
df["MaritalDesc"].unique()
# Out:
# array(['Single', 'Married', 'Divorced', 'Widowed', 'Separated'],
#       dtype=object)

# %%
df["CitizenDesc"].unique()
# Out:
# array(['US Citizen', 'Eligible NonCitizen', 'Non-Citizen'], dtype=object)

# %%
df["HispanicLatino"].unique()
# Out:
# array(['No', 'Yes', 'no', 'yes'], dtype=object)

# %%
# Problem Statement
# there is duplicate value in HispanicLatino column

# %%
df["RaceDesc"].unique()
# Out:
# array(['White', 'Black or African American', 'Two or more races', 'Asian',
#        'American Indian or Alaska Native', 'Hispanic'], dtype=object)

# %%
df["DateofHire"].sort_values(ascending = True)
# Out:
# 300    1/10/2011
# 286    1/10/2011
# 146    1/10/2011
# 236    1/10/2011
# 24     1/10/2011
#          ...
# 27     9/30/2013
# 252    9/30/2014
# 48      9/5/2012
# 98      9/6/2011
# 42      9/6/2016
# Name: DateofHire, Length: 311, dtype: object

# %%
# Problem Statement 
# DateofHire dtype

# %%
df["EmploymentStatus"].unique()
# Out:
# array(['Active', 'Voluntarily Terminated', 'Terminated for Cause'],
#       dtype=object)

# %%
df["Department"].unique()
# Out:
# array(['Production       ', 'IT/IS', 'Software Engineering',
#        'Admin Offices', 'Sales', 'Executive Office'], dtype=object)

# %%
# Problem Statement
# Having extra space in Production attributes in Department column

# %%
df["ManagerName"].unique()
# Out:
# array(['Michael Albert', 'Simon Roup', 'Kissy Sullivan', 'Elijiah Gray',
#        'Webster Butler', 'Amy Dunn', 'Alex Sweetwater', 'Ketsia Liebig',
#        'Brannon Miller', 'Peter Monroe', 'David Stanley', 'Kelley Spirea',
#        'Brandon R. LeBlanc', 'Janet King', 'John Smith',
#        'Jennifer Zamora', 'Lynn Daneault', 'Eric Dougall',
#        'Debra Houlihan', 'Brian Champaigne', 'Board of Directors'],
#       dtype=object)

# %%
df["ManagerID"].unique()
# Out:
# array([22.,  4., 20., 16., 39., 11., 10., 19., 12.,  7., 14., 18., nan,
#         3.,  2.,  1., 17.,  5., 21.,  6., 15., 13.,  9., 30.])

# %%
# problem Statement
# in ManagerID column having nan value

# %%
df["RecruitmentSource"].unique()
# Out:
# array(['LinkedIn', 'Indeed', 'Google Search', 'Employee Referral',
#        'Diversity Job Fair', 'On-line Web application', 'CareerBuilder',
#        'Website', 'Other'], dtype=object)

# %%
df["PerformanceScore"].unique()
# Out:
# array(['Exceeds', 'Fully Meets', 'Needs Improvement', 'PIP'], dtype=object)

# %%
df["EngagementSurvey"].unique()
# Out:
# array([4.6 , 4.96, 3.02, 4.84, 5.  , 3.04, 4.46, 4.2 , 4.28, 4.4 , 4.5 ,
#        2.  , 4.8 , 3.5 , 3.39, 3.35, 3.19, 3.14, 4.51, 3.25, 3.84, 4.43,
#        3.3 , 3.8 , 3.  , 4.3 , 3.58, 4.7 , 4.1 , 4.13, 3.7 , 4.73, 4.12,
#        4.62, 3.1 , 3.96, 3.79, 1.93, 1.12, 3.01, 2.3 , 3.88, 3.4 , 4.11,
#        4.77, 4.52, 2.9 , 2.1 , 4.  , 3.13, 1.56, 1.2 , 4.76, 3.66, 3.73,
#        4.24, 3.97, 3.9 , 4.61, 4.63, 4.64, 4.17, 3.6 , 3.03, 4.48, 3.24,
#        3.72, 2.34, 3.99, 3.75, 3.07, 4.83, 3.49, 3.38, 3.65, 4.78, 4.9 ,
#        4.88, 4.53, 3.18, 4.65, 3.08, 3.93, 4.18, 4.37, 2.39, 3.81, 4.29,
#        2.33, 4.25, 3.89, 3.54, 2.4 , 3.45, 4.16, 3.17, 4.15, 3.98, 4.36,
#        3.69, 4.94, 2.6 , 3.51, 3.31, 4.81, 3.32, 4.68, 3.27, 1.81, 4.21,
#        2.44, 2.81, 4.33, 3.21, 3.11, 2.5 , 3.42, 4.07, 3.2 ])

# %%
df["SpecialProjectsCount"].unique()
# Out:
# array([0, 6, 4, 5, 7, 3, 8, 2, 1], dtype=int64)

# %%
df["LastPerformanceReview_Date"].unique()
# Out:
# array(['1/17/2019', '2/24/2016', '5/15/2012', '1/3/2019', '2/1/2016',
#        '1/7/2019', '1/2/2019', '2/25/2019', '1/25/2019', '2/18/2019',
#        '1/30/2016', '5/6/2016', '2/14/2019', '3/2/2017', '4/5/2017',
#        '1/14/2019', '1/15/2015', '1/11/2019', '1/10/2019', '2/27/2019',
#        '3/4/2014', '1/10/2016', '2/20/2014', '3/4/2013', '1/15/2019',
#        '2/1/2019', '1/21/2019', '2/10/2013', '2/21/2019', '2/22/2019',
#        '1/30/2019', '2/12/2019', '2/19/2019', '1/19/2019', '3/10/2015',
#        '5/3/2012', '5/4/2011', '2/28/2019', '5/1/2016', '2/4/2019',
#        '1/22/2019', '1/28/2019', '1/24/2019', '1/31/2019', '4/2/2016',
#        '5/6/2015', '1/23/2019', '1/29/2019', '1/18/2019', '1/4/2019',
#        '1/27/2019', '4/9/2017', '2/13/2019', '4/12/2018', '1/15/2017',
#        '8/10/2012', '2/4/2016', '4/5/2013', '1/7/2012', '2/8/2019',
#        '2/26/2019', '1/16/2019', '4/29/2016', '1/15/2014', '1/20/2015',
# ...

# %%
#Problem statement
# Dtype is wrong in lastperformace review date column

# %%
df["DaysLateLast30"].unique()
# Out:
# array([0, 2, 1, 5, 3, 6, 4], dtype=int64)

# %%
df["Absences"].unique()
# Out:
# array([ 1, 17,  3, 15,  2, 19,  4, 16, 12,  9,  7, 20,  8, 13,  5, 14,  6,
#        11, 10, 18], dtype=int64)

# %% [markdown]
# ## Data Cleaning Part

# %%
# Removing commas from Employee_Name column
df['Employee_Name'] = df['Employee_Name'].str.replace(',', '')

# %%
df['Employee_Name']
# Out:
# 0           Adinolfi Wilson  K
# 1      Ait Sidi Karthikeyan
# 2             Akinkuolie Sarah
# 3                  AlagbeTrina
# 4              Anderson Carol
#                 ...
# 306              Woodson Jason
# 307          Ybarra Catherine
# 308            Zamora Jennifer
# 309                 Zhou Julia
# 310               Zima Colleen
# Name: Employee_Name, Length: 311, dtype: object

# %%
# filling null value of column ManagerID with moode
df['ManagerID'].fillna(df['ManagerID'].mode()[0], inplace = True)

# %%
df['ManagerID'].isnull().sum()
# Out:
# 0

# %%
# Cleaning of DOB column
def subtract_years(date):
    if date.year > 2000:
        return date.replace(year=date.year-100)
    else:
        return date
    
    df["DOB"] = df["DOB"].apply(subtract_years).dt.strftime('%d-%m-%Y')

# %%
df["DOB"] = pd.to_datetime(df["DOB"])
df["DOB"].sort_values(ascending= True)
# Out:
# 232   1973-01-12
# 174   1973-02-14
# 261   1973-03-12
# 265   1973-03-26
# 243   1973-04-05
#          ...
# 234   2072-07-03
# 127   2072-08-27
# 139   2072-09-11
# 175   2072-11-09
# 240   2072-11-21
# Name: DOB, Length: 311, dtype: datetime64[ns]

# %%
# replacing duplicate value of HispanicLatino column

replace_dict = {'yes': 'Yes', 'no':'No'}
df['HispanicLatino'] = df['HispanicLatino'].replace(replace_dict)

# %%
df['HispanicLatino'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# changing data type of DateofHire colum

df["DateofHire"] = pd.to_datetime(df["DateofHire"])

# %%
df['DateofHire'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 311 entries, 0 to 310
# Series name: DateofHire
# Non-Null Count  Dtype
# --------------  -----
# 311 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.6 KB

# %%
# Removing extra space from Production attributes in Department column
replace_production = {'Production       ': 'Production'}
df['Department'] = df['Department'].replace(replace_production)

# %%
df['Department'].unique()
# Out:
# array(['Production', 'IT/IS', 'Software Engineering', 'Admin Offices',
#        'Sales', 'Executive Office'], dtype=object)

# %%
#typecastin of Manager ID from float to int

df['ManagerID'] = df['ManagerID'].astype(int)

# %%
df['ManagerID'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 311 entries, 0 to 310
# Series name: ManagerID
# Non-Null Count  Dtype
# --------------  -----
# 311 non-null    int32
# dtypes: int32(1)
# memory usage: 1.3 KB

# %%
df['ManagerID'].unique()
# Out:
# array([22,  4, 20, 16, 39, 11, 10, 19, 12,  7, 14, 18,  3,  2,  1, 17,  5,
#        21,  6, 15, 13,  9, 30])

# %%
#changing dtype of lastperformace column to datetime

df['LastPerformanceReview_Date'] = pd.to_datetime(df['LastPerformanceReview_Date'])

# %%
df['LastPerformanceReview_Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 311 entries, 0 to 310
# Series name: LastPerformanceReview_Date
# Non-Null Count  Dtype
# --------------  -----
# 311 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 2.6 KB

# %% [markdown]
# ## Data Visulization part

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
# Checking the employment status of Employess using piechart

employment_status_counts = df.groupby('EmploymentStatus').size()

plt.pie(employment_status_counts, labels=employment_status_counts.index, autopct='%1.1f%%')


plt.title('Employment Status of Employees')
plt.show()

# %%
sns.boxplot(x='DeptID', y='Salary', data=df)
# Out:
# <Axes: xlabel='DeptID', ylabel='Salary'>

# %% [markdown]
# Got to know that the person fall under DeptID 4 getting more salary compare to others

# %%
grouped = df.groupby('Position')['Salary'].mean()

grouped = grouped.sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(grouped.index, grouped.values)

ax.set_xlabel('Salary')
ax.set_ylabel('Position')
ax.set_title('Average Salary by Position')

plt.show()

# %% [markdown]
# Got the insight about Salary with respect to the position

# %%
plt.hist(df['PerformanceScore'], bins=30)

plt.xlabel('Performance')
plt.ylabel('Score')
plt.title('Performance Distribution')

plt.show()

# %% [markdown]
# Most of the employees fully meets the performace

# %%
Recruitment = df.groupby('RecruitmentSource').size()

plt.pie(Recruitment, labels=Recruitment.index, autopct='%1.1f%%')


plt.title('RecruitmentSource')
plt.show()

# %% [markdown]
# Most of the people recruited via Indeed & linkedIn

# %%
grouped = df.groupby('TermReason')['Employee_Name'].count().reset_index(name='Count')
grouped = grouped.sort_values('Count', ascending=False)

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='Count', y='TermReason', data=grouped, ax=ax)
ax.set_title('Termination Reasons')
ax.set_xlabel('Count')
ax.set_ylabel('Reason')

plt.show()

# %% [markdown]
# Most Termination reason is another position

# %%
grouped = df.groupby('MaritalDesc')['Employee_Name'].count()

fig, ax = plt.subplots(figsize=(8, 6))
ax.pie(grouped.values, labels=grouped.index, autopct='%1.1f%%')

ax.set_title('Employees by Marital Status')

plt.show()

# %% [markdown]
# Got the insight that the most of the employess of this company are Single

# %%
grouped = df.groupby('Sex')['Employee_Name'].count()

fig, ax = plt.subplots(figsize=(8, 6))
ax.bar(grouped.index, grouped.values)

ax.set_title('Employees by Sex')
ax.set_xlabel('Sex')
ax.set_ylabel('Number of Employees')

plt.show()

# %% [markdown]
# Got the insights that the Female Employee are comparetively higher than Male Employee

# %%
grouped = df.groupby(['Sex', 'Position'])['Employee_Name'].count()

fig, ax = plt.subplots(figsize=(10, 8))
grouped.plot(kind='bar', ax=None)

ax.set_title('Employees by Sex and Position')
ax.set_xlabel('Sex')
ax.set_ylabel('Number of Employees')

plt.show()

# %% [markdown]
# Comparision box plot chart of the Employees by sex and position

# %%
grouped = df.groupby(['Position', 'PerfScoreID'])['Employee_Name'].count()

ax = grouped.plot(kind='bar', figsize=(10, 6))

ax.set_title('Position vs Performance Score')
ax.set_xlabel('Position')
ax.set_ylabel('Number of Employees')

ax.legend(title='Performance Score')
plt.show()

# %% [markdown]
# Got the insight using box plot about Position vs Performance Score

# %%
df.to_csv("Cleaned_HR_ Dataset", index = False)
